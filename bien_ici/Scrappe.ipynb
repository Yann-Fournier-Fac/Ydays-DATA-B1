# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import time

# Garder la page ouverte
chrome_options = Options() 
chrome_options.add_experimental_option("detach", True)

# On recupere le controle du driver
DRIVER_PATH = "./chromedriver"
driver = webdriver.Chrome(DRIVER_PATH, options=chrome_options)
driver.implicitly_wait(5)

driver.get("https://www.bienici.com/recherche/achat/hauts-de-seine-92/appartement?prix-max=300000")
try:
    driver.find_element(By.XPATH, "/html/body/div[1]/div/div/div/div/div/div[3]/button[2]").click()
except:
    pass

h2 = driver.find_element(By.XPATH, "/html/body/div[2]/div[3]/div[3]/div/div[1]/div[3]/div[3]/div[2]/div/span/h2").text
nbr_element = int(h2.replace(" ", "")[:4])
print(nbr_element)

nbr_page = int((nbr_element - (nbr_element % 26)) /26)
nbr_element_derniere_page = nbr_element % 26
# print(nbr_page)
# print(nbr_element_derniere_page)

CodePostal = []
Prix = []
PrixMetreCarre = []
MetreCarre = []
NbrPiece = []
cpt = 0
nbr = 26

#for i in range(1, nbr_page+1):
for i in range(1, 2):
    try:
        driver.get("https://www.bienici.com/recherche/achat/hauts-de-seine-92/appartement?prix-max=300000&page=" + str(i))
        time.sleep(1)
        try:
            driver.find_element(By.XPATH, "/html/body/div[1]/div/div/div/div/div/div[3]/button[2]").click()
        except:
            pass
    except:
        print(i, y, "pas ok")

    if (i == nbr_page+1):
        nbr = nbr_element_derniere_page 

    for y in range(1, nbr+1):
        try:
            driver.find_element(By.XPATH, "/html/body/div[2]/div[30]/div/div/div/div/button").click()
            time.sleep(1)
        except:
            pass
        try :
            driver.find_element(By.XPATH, f"/html/body/div[2]/div[3]/div[3]/div/div[2]/section/div/div[1]/article["+ str(y) +"]/div/div/div/div[1]/div/div[2]/div/div[2]/a").click()
            time.sleep(1)

            try:
                codepostal = driver.find_element(By.XPATH, "/html/body/div[2]/section/div/div[3]/div[1]/div[1]/h1/span").text
                codepostal = int(codepostal.replace(" ", "")[:5])
            except:
                pass
            try:
                prix = driver.find_element(By.XPATH, "/html/body/div[2]/section/div/div[3]/div[1]/div[1]/div[2]/div[1]/div[1]/div/div/span[1]").text
                prix = int(prix.replace(" ","")[:-1])
            except:
                pass
            try:
                prixmetrecarre = driver.find_element(By.XPATH,"/html/body/div[2]/section/div/div[3]/div[1]/div[1]/div[2]/div[1]/div[1]/div/div/span[2]").text
                try:
                    prixmetrecarre = int(prixmetrecarre.replace(" ","")[:-4])
                except:
                    prixmetrecarre = int(prixmetrecarre.replace(" ","")[:-5]) 
            except:
                pass
            try:
                metrecarre = driver.find_element(By.XPATH, "/html/body/div[2]/section/div/div[3]/section[3]/div[1]/div[4]/span").text
                metrecarre = float(metrecarre.replace(" ","")[:-2].replace(",","."))
            except:
                pass
            try:
                nbrpiece = driver.find_element(By.XPATH, "/html/body/div[2]/section/div/div[3]/section[3]/div[1]/div[5]/span").text
                try:
                    nbrpiece = int(nbrpiece.replace(" ","")[:-5])
                except:
                    nbrpiece = int(nbrpiece.replace(" ","")[:-6]) 
            except:
                pass
            print(codepostal, prix, prixmetrecarre, metrecarre, nbrpiece)

            CodePostal.append(codepostal)
            Prix.append(prix)
            PrixMetreCarre.append(prixmetrecarre)
            MetreCarre.append(metrecarre)
            NbrPiece.append(nbrpiece)

            print(i, y, "ok")
            time.sleep(1)
            cpt += 1
            driver.back()
        except:
            print(i, y, "pas ok", 1)

        # if truc == False:
        #     try:
        #         driver.find_element(By.XPATH, f"/html/body/div[2]/div[3]/div[3]/div/div[2]/section/div/div[1]/div/div/article["+ str(y)+ "]/div/div/div/div[1]/div/div[2]/div/div[2]/a").click()
        #         print(i, y, "ok", 2)
        #         time.sleep(1)
        #         driver.back()
        #     except:
        #         print(i, y, "pas ok", 2)



driver.close()
driver.quit()
print(cpt)
# Out:
# /var/folders/1_/54_5j3cn25jd5mt0cyzggqj80000gn/T/ipykernel_20411/3947265625.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(DRIVER_PATH, options=chrome_options)
# 2113
# 92600 248000 3139 79.0 4
# 1 1 ok
# 92270 228000 6318 34.17 2
# 1 2 ok
# 92700 269000 6231 43.17 2
# 1 3 ok
# 92270 199000 5758 33.0 2
# 1 4 ok
# 92220 202464 6922 29.25 1
# 1 5 ok
# 92200 160000 13,3k €/m² 12.0 1
# 1 6 ok
# 92800 210000 7778 27.0 1
# 1 7 ok
# 92700 295000 6146 48.0 2
# 1 8 ok
# 1 9 pas ok 1
# 1 10 pas ok 1
# 1 11 pas ok 1
# 1 12 pas ok 1
# 1 13 pas ok 1
# 1 14 pas ok 1
# 1 15 pas ok 1
# 1 16 pas ok 1
# 1 17 pas ok 1
# 1 18 pas ok 1
# 1 19 pas ok 1
# 1 20 pas ok 1
# 1 21 pas ok 1
# 1 22 pas ok 1
# 1 23 pas ok 1
# 1 24 pas ok 1
# 1 25 pas ok 1
# 1 26 pas ok 1
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# /Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb Cellule 1 in 1
#     <a href='vscode-notebook-cell:/Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb#W0sZmlsZQ%3D%3D?line=107'>108</a>             print(i, y, "pas ok", 1)
#     <a href='vscode-notebook-cell:/Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb#W0sZmlsZQ%3D%3D?line=109'>110</a>         # if truc == False:
#     <a href='vscode-notebook-cell:/Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb#W0sZmlsZQ%3D%3D?line=110'>111</a>         #     try:
#     <a href='vscode-notebook-cell:/Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb#W0sZmlsZQ%3D%3D?line=111'>112</a>         #         driver.find_element(By.XPATH, f"/html/body/div[2]/div[3]/div[3]/div/div[2]/section/div/div[1]/div/div/article["+ str(y)+ "]/div/div/div/div[1]/div/div[2]/div/div[2]/a").click()
#    (...)
#     <a href='vscode-notebook-cell:/Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb#W0sZmlsZQ%3D%3D?line=115'>116</a>         #     except:
#     <a href='vscode-notebook-cell:/Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb#W0sZmlsZQ%3D%3D?line=116'>117</a>         #         print(i, y, "pas ok", 2)
# --> <a href='vscode-notebook-cell:/Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb#W0sZmlsZQ%3D%3D?line=120'>121</a> driver.close()
#     <a href='vscode-notebook-cell:/Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb#W0sZmlsZQ%3D%3D?line=121'>122</a> driver.quit()
#     <a href='vscode-notebook-cell:/Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb#W0sZmlsZQ%3D%3D?line=122'>123</a> print(cpt)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:561, in WebDriver.close(self)
#     552 def close(self) -> None:
#     553     """
#     554     Closes the current window.
#     555
#    (...)
#     559             driver.close()
#     560     """
# --> 561     self.execute(Command.CLOSE)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=112.0.5615.121)
# Stacktrace:
# 0   chromedriver                        0x0000000102972ae8 chromedriver + 4958952
# 1   chromedriver                        0x000000010296a7b3 chromedriver + 4925363
# 2   chromedriver                        0x000000010252c1d6 chromedriver + 475606
# 3   chromedriver                        0x0000000102501cec chromedriver + 302316
# 4   chromedriver                        0x000000010259af2f chromedriver + 929583
# 5   chromedriver                        0x00000001025a1c7c chromedriver + 957564
# 6   chromedriver                        0x0000000102595bd8 chromedriver + 908248
# 7   chromedriver                        0x000000010255faef chromedriver + 686831
# 8   chromedriver                        0x000000010256100e chromedriver + 692238
# 9   chromedriver                        0x000000010292e9ad chromedriver + 4680109
# 10  chromedriver                        0x0000000102933c12 chromedriver + 4701202
# 11  chromedriver                        0x000000010293a79f chromedriver + 4728735
# 12  chromedriver                        0x0000000102934b7a chromedriver + 4705146
# 13  chromedriver                        0x000000010290727e chromedriver + 4518526
# 14  chromedriver                        0x0000000102954908 chromedriver + 4835592
# 15  chromedriver                        0x0000000102954a87 chromedriver + 4835975
# 16  chromedriver                        0x000000010296400f chromedriver + 4898831
# 17  libsystem_pthread.dylib             0x00007ff817090259 _pthread_start + 125
# 18  libsystem_pthread.dylib             0x00007ff81708bc7b thread_start + 15

# %%
# Out:
# 2113
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb Cellule 2 in 3
#       <a href='vscode-notebook-cell:/Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> print(int(h2.replace(" ", "")[:4]))
#       <a href='vscode-notebook-cell:/Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> for i in range(len(Prix)):
# ----> <a href='vscode-notebook-cell:/Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a>     print(CodePostal[i], Prix[i], PrixMetreCarre[i], MetreCarre[i] ,NbrPiece[i])
#       <a href='vscode-notebook-cell:/Users/yann/Desktop/cours_Ynov/Ydays/Data/bien_ici/Scrappe.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> print(cpt)
#
# NameError: name 'CodePostal' is not defined
